# %%
from skelesign import plotting
from skelesign.data import load_data
from skelesign.config import config
import torch

# %% [markdown]
# ## Exploration on SLP dataset
#
# Objectives of this notebook:
# * Visualize text and skeleton data in order to grasp the structures.
# * Develop helpers to load and visualize the data.
# * Try to find out potential improvements for the models presented (perhaps belongs to other NB)

# %% [markdown]
# #### Skeleton structure
#
#     Definition of skeleton model structure:
#       The structure is an n-tuple of:
#
#       (index of a start point, index of an end point, index of a bone)
#
#       E.g., this simple skeletal model
#
#                 (0)
#                  |
#                  |
#                  0
#                  |
#                  |
#         (2)--1--(1)--1--(3)
#          |               |
#          |               |
#          2               2
#          |               |
#          |               |
#         (4)             (5)
#
#       has this structure:
#
#       (
#         (0, 1, 0),
#         (1, 2, 1),
#         (1, 3, 1),
#         (2, 4, 2),
#         (3, 5, 2),
#       )
#
#      Warning 1: The structure has to be a tree.
#      Warning 2: The order isn't random. The order is from a root to lists.

# %%
train_data, dev_data, test_data, src_vocab, trg_vocab = load_data(config)

# %%
train_data[1].src
# Out:
# ['ORT', 'REGEN', 'DURCH', 'REGEN', 'KOENNEN', 'UEBERSCHWEMMUNG', 'KOENNEN']

# %%
temp = [i[-1] for i in train_data[3].trg]
[i - j for (i, j) in zip(temp, temp[1:])]
# Out:
# [tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0055),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0055),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0055),
#  tensor(-0.0054),
#  tensor(-0.0054),
#  tensor(-0.0054),
# ...

# %%
plotting.plot_video(train_data[0].trg, ".", "test")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 plotting.plot_video(train_data[0].trg, ".", "test")
#
# File ~/projects/slp/slp/skelesign/plotting.py:38, in plot_video(joints, file_path, video_name, references, skip_frames, sequence_ID)
#      34 for (j, frame_joints) in enumerate(joints):
#      35
#      36     # Reached padding
#      37     breakpoint()
# ---> 38     if PAD_TOKEN in frame_joints:
#      39         continue
#      41     # Initialise frame of white
#
# File ~/.pyenv/versions/3.9.5/envs/nlp-3.9.5/lib/python3.9/site-packages/torch/_tensor.py:705, in Tensor.__contains__(self, element)
#     701 if isinstance(element, (torch.Tensor, Number)):
#     702     # type hint doesn't understand the __contains__ result array
#     703     return (element == self).any().item()  # type: ignore[union-attr]
# --> 705 raise RuntimeError(
# ...
